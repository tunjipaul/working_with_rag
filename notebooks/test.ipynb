# %%
import numpy as np
print(np.__version__)
# Out:
# 2.4.0

# %%
import pydantic
print(f"Pydantic version: {pydantic.__version__}")
# Out:
# Pydantic version: 2.12.5

# %%
# !pip uninstall pydantic -y
# !pip install "pydantic<2"
# Out:
# Found existing installation: pydantic 2.12.5
# Uninstalling pydantic-2.12.5:
#   Successfully uninstalled pydantic-2.12.5
# Collecting pydantic<2
#   Using cached pydantic-1.10.26-cp314-cp314-win_amd64.whl.metadata (156 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\hp pc\desktop\tunjipaul\working_with_rag\myenv\lib\site-packages (from pydantic<2) (4.15.0)
# Using cached pydantic-1.10.26-cp314-cp314-win_amd64.whl (2.0 MB)
# Installing collected packages: pydantic
# Successfully installed pydantic-1.10.26
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-genai 1.55.0 requires pydantic<3.0.0,>=2.9.0, but you have pydantic 1.10.26 which is incompatible.
# langchain 1.1.3 requires pydantic<3.0.0,>=2.7.4, but you have pydantic 1.10.26 which is incompatible.
# langchain-classic 1.0.0 requires pydantic<3.0.0,>=2.7.4, but you have pydantic 1.10.26 which is incompatible.
# langchain-core 1.1.3 requires pydantic<3.0.0,>=2.7.4, but you have pydantic 1.10.26 which is incompatible.
# langchain-google-genai 4.0.0 requires pydantic<3.0.0,>=2.0.0, but you have pydantic 1.10.26 which is incompatible.
# langgraph 1.0.4 requires pydantic>=2.7.4, but you have pydantic 1.10.26 which is incompatible.
# pydantic-settings 2.12.0 requires pydantic>=2.7.0, but you have pydantic 1.10.26 which is incompatible.

# %%
import chromadb
print(f"ChromaDB version: {chromadb.__version__}")
# Out:
# ChromaDB version: 0.3.23

# %%
import pydantic
print(f"Pydantic version: {pydantic.__version__}")
# Out:
# Pydantic version: 2.12.5
